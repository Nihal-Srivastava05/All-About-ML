# %% [markdown]
# # Welcome to Pandas ...

# %% [markdown]
# ## What is Pandas?
#
# Pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %%
import pandas as pd

# %% [markdown]
# ## Building DataFrames with Pandas

# %% [markdown]
# ### From Python Dictionaries

# %%
list1 = ['S1','S2','S3','S4']
English = [89,90,78,98]
Maths = [67,90,100,100]
Science = [78,89,90,89]

titles = ['ID', 'English','Maths','Science']
values = [list1,English,Maths,Science]
result = list(zip(titles,values))
result
# Out:
# [('ID', ['S1', 'S2', 'S3', 'S4']),
#  ('English', [89, 90, 78, 98]),
#  ('Maths', [67, 90, 100, 100]),
#  ('Science', [78, 89, 90, 89])]

# %%
result1 = dict(result)
df1 = pd.DataFrame(result1)
print(df1)
# Out:
#    ID  English  Maths  Science
# 0  S1       89     67       78
# 1  S2       90     90       89
# 2  S3       78    100       90
# 3  S4       98    100       89

# %% [markdown]
# ## Importing data

# %% [markdown]
# ###  Dataframes from CSV files

# %%
# df2 = pd.read_csv('E:\\ML online\\Session - IV\\Pandas\\got-character-deaths.csv')
df2 = pd.read_csv('character-deaths.csv')
df2.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
df2.tail()
# Out:
#                   Name Allegiances  Death Year  Book of Death  Death Chapter  \
# 912              Zollo        None         NaN            NaN            NaN
# 913  Yurkhaz zo Yunzak        None       300.0            5.0           59.0
# 914   Yezzan Zo Qaggaz        None       300.0            5.0           57.0
# 915   Torwynd the Tame    Wildling       300.0            5.0           73.0
# 916      Talbert Serry      Tyrell       300.0            4.0           29.0
#
#      Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  DwD
# 912                21.0       1         0    0    0    1    0    0
# 913                47.0       1         0    0    0    0    0    1
# 914                25.0       1         1    0    0    0    0    1
# 915                73.0       1         0    0    0    1    0    0
# 916                29.0       1         1    0    0    0    1    0

# %% [markdown]
# ### Try by yourself...

# %%
###  Remove headers from the csv file and import
###  Then,add header to it

#Display first 10 lines of the file
df2.head(10)
# Out:
#                                 Name      Allegiances  Death Year  \
# 0                     Addam Marbrand        Lannister         NaN
# 1            Aegon Frey (Jinglebell)             None       299.0
# 2                    Aegon Targaryen  House Targaryen         NaN
# 3                      Adrack Humble    House Greyjoy       300.0
# 4                     Aemon Costayne        Lannister         NaN
# 5                    Aemon Estermont        Baratheon         NaN
# 6  Aemon Targaryen (son of Maekar I)    Night's Watch       300.0
# 7                         Aenys Frey             None       300.0
# 8                      Aeron Greyjoy    House Greyjoy         NaN
# 9                             Aethan    Night's Watch         NaN
#
#    Book of Death  Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  \
# 0            NaN            NaN                56.0       1         1    1
# 1            3.0           51.0                49.0       1         1    0
# 2            NaN            NaN                 5.0       1         1    0
# 3            5.0           20.0                20.0       1         1    0
# 4            NaN            NaN                 NaN       1         1    0
# 5            NaN            NaN                 NaN       1         1    0
# 6            4.0           35.0                21.0       1         1    1
# 7            5.0            NaN                59.0       0         1    1
# 8            NaN            NaN                11.0       1         1    0
# 9            NaN            NaN                 0.0       1         0    0
#
#    CoK  SoS  FfC  DwD
# 0    1    1    1    0
# 1    0    1    0    0
# 2    0    0    0    1
# 3    0    0    0    1
# 4    0    1    0    0
# 5    1    1    0    0
# 6    0    1    1    0
# 7    1    1    0    1
# 8    1    0    1    0
# 9    0    1    0    0

# %% [markdown]
# ## Saving processed data frames

# %% [markdown]
# ###  To CSV File

# %%
df2.to_csv('E:\\ML Online\\Session - IV\\Pandas\\result.csv')

# %% [markdown]
# ## Try Yourselves....

# %%
### Open a file with xls as extension and save it back as a csv file

# %% [markdown]
# ## Pandas - Operations

# %% [markdown]
# ### Creating index for entities...

# %%
df2.set_index("Gender")
# print(df2.head)
# Out:
#                            Name      Allegiances  Death Year  Book of Death  \
# Gender
# 1                Addam Marbrand        Lannister         NaN            NaN
# 1       Aegon Frey (Jinglebell)             None       299.0            3.0
# 1               Aegon Targaryen  House Targaryen         NaN            NaN
# 1                 Adrack Humble    House Greyjoy       300.0            5.0
# 1                Aemon Costayne        Lannister         NaN            NaN
# ...                         ...              ...         ...            ...
# 1                         Zollo             None         NaN            NaN
# 1             Yurkhaz zo Yunzak             None       300.0            5.0
# 1              Yezzan Zo Qaggaz             None       300.0            5.0
# 1              Torwynd the Tame         Wildling       300.0            5.0
# 1                 Talbert Serry           Tyrell       300.0            4.0
#
#         Death Chapter  Book Intro Chapter  Nobility  GoT  CoK  SoS  FfC  DwD
# Gender
# 1                 NaN                56.0         1    1    1    1    1    0
# 1                51.0                49.0         1    0    0    1    0    0
# 1                 NaN                 5.0         1    0    0    0    0    1
# 1                20.0                20.0         1    0    0    0    0    1
# 1                 NaN                 NaN         1    0    0    1    0    0
# ...               ...                 ...       ...  ...  ...  ...  ...  ...
# 1                 NaN                21.0         0    0    0    1    0    0
# 1                59.0                47.0         0    0    0    0    0    1
# 1                57.0                25.0         1    0    0    0    0    1
# 1                73.0                73.0         0    0    0    1    0    0
# 1                29.0                29.0         1    0    0    0    1    0
#
# [917 rows x 12 columns]

# %% [markdown]
# ### Type and information about dataframe

# %%
# print("Type:\n",type(df2))
print("Information about the dataframe:",df2.info())
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                917 non-null    object
#  1   Allegiances         917 non-null    object
#  2   Death Year          305 non-null    float64
#  3   Book of Death       307 non-null    float64
#  4   Death Chapter       299 non-null    float64
#  5   Book Intro Chapter  905 non-null    float64
#  6   Gender              917 non-null    int64
#  7   Nobility            917 non-null    int64
#  8   GoT                 917 non-null    int64
#  9   CoK                 917 non-null    int64
#  10  SoS                 917 non-null    int64
#  11  FfC                 917 non-null    int64
#  12  DwD                 917 non-null    int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 93.3+ KB
# Information about the dataframe: None
#        Death Year  Book of Death  Death Chapter  Book Intro Chapter  \
# count  305.000000     307.000000     299.000000          905.000000
# mean   299.157377       2.928339      40.070234           28.861878
# std      0.703483       1.326482      20.470270           20.165788
# min    297.000000       1.000000       0.000000            0.000000
# 25%    299.000000       2.000000      25.500000           11.000000
# 50%    299.000000       3.000000      39.000000           27.000000
# 75%    300.000000       4.000000      57.000000           43.000000
# max    300.000000       5.000000      80.000000           80.000000
#
#            Gender    Nobility         GoT         CoK         SoS         FfC  \
# count  917.000000  917.000000  917.000000  917.000000  917.000000  917.000000
# mean     0.828790    0.468920    0.272628    0.353326    0.424209    0.272628
# std      0.376898    0.499305    0.445554    0.478264    0.494492    0.445554
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               DwD
# count  917.000000
# mean     0.284624
# std      0.451481
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
print("Shape of datafframe:",df2.shape)
df2.drop_duplicates()
print(df2.shape)
# Out:
# Shape of datafframe: (917, 13)
# (917, 13)

# %% [markdown]
# ### Try Yourselves ...

# %%
### Append same data in df2 to df2 itself using append function
df2 = df2.append(df2)
### print its shape
print(df2.shape)
### Use drop_duplicates to remove duplicate
df2 = df2.drop_duplicates()
### print shape again
print(df2.shape)
# Out:
# (1834, 13)
# (917, 13)

# %%
print("Columns of dataframe:\t",df2.columns)
# Out:
# Columns of dataframe:	 Index(['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
df2.rename(columns={'Book of Death':'BoD'},inplace=True)
print("Columns of dataframe:\t",df2.columns)
# Out:
# Columns of dataframe:	 Index(['Name', 'Allegiances', 'Death Year', 'BoD', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
print(df2.describe())
# Out:
#        Death Year         BoD  Death Chapter  Book Intro Chapter      Gender  \
# count  305.000000  307.000000     299.000000          905.000000  917.000000
# mean   299.157377    2.928339      40.070234           28.861878    0.828790
# std      0.703483    1.326482      20.470270           20.165788    0.376898
# min    297.000000    1.000000       0.000000            0.000000    0.000000
# 25%    299.000000    2.000000      25.500000           11.000000    1.000000
# 50%    299.000000    3.000000      39.000000           27.000000    1.000000
# 75%    300.000000    4.000000      57.000000           43.000000    1.000000
# max    300.000000    5.000000      80.000000           80.000000    1.000000
#
#          Nobility         GoT         CoK         SoS         FfC         DwD
# count  917.000000  917.000000  917.000000  917.000000  917.000000  917.000000
# mean     0.468920    0.272628    0.353326    0.424209    0.272628    0.284624
# std      0.499305    0.445554    0.478264    0.494492    0.445554    0.451481
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000

# %%
print("No. of chapters talking about death:\t",df2['Death Chapter'].count())
print("No. of unique chapters talking about death:\t",df2['Death Chapter'].nunique())
print("Unique chapters talking about death:\t",df2['Death Chapter'].unique())
# Out:
# No. of chapters talking about death:	 299
# No. of unique chapters talking about death:	 71
# Unique chapters talking about death:	 [nan 51. 20. 35. 56.  4. 46. 10. 34. 47. 41. 21. 33. 39. 52. 37. 24. 31.
#  27. 62. 65.  7. 49. 50. 42. 30. 66. 64. 29.  0. 53. 58. 76. 63. 55. 14.
#  61. 12. 68. 69. 80. 36.  1. 19. 72. 59. 43. 70. 75. 11.  3. 60. 26. 44.
#  67. 45. 18. 23. 57. 25. 16. 17. 48.  9.  2.  6. 32. 77. 74. 40. 38. 73.]

# %% [markdown]
# ## Accessing using Index - .iloc
#
# #### Argument can be,
#
# * integer -> 3
# * list of integers -> [3,5,7,8]
# * slice objects -> 0:9
#
# Eg:
#
# * data-frame**.iloc[4]**                    -> Gets row 4
# * data-frame**.iloc[[2,3,4,5], [2,4]]**     -> Gets rows 2,3,4,5 with columns 2 and 4
# * data-frame**.iloc[:5, 1:3]**              -> Gets rows 0 to 4 with columns 1 to 2
#
# *Note - if slice is a:b, then a is included, b is excluded*

# %%
print("First five values of 'Allegiances' column\t:\n",df2.iloc[0:5,0])
# Out:
# First five values of 'Allegiances' column	:
#  0             Addam Marbrand
# 1    Aegon Frey (Jinglebell)
# 2            Aegon Targaryen
# 3              Adrack Humble
# 4             Aemon Costayne
# Name: Name, dtype: object

# %% [markdown]
# ## Accessing using location - .loc[ ]

# %%
#print(df2.head())
# df2.set_index('Name',inplace=True)
print(df2.head())
print(df2.loc['Adrack Humble','Death Year'])
# Out:
#                              Allegiances  Death Year  BoD  Death Chapter  \
# Name
# Addam Marbrand                 Lannister         NaN  NaN            NaN
# Aegon Frey (Jinglebell)             None       299.0  3.0           51.0
# Aegon Targaryen          House Targaryen         NaN  NaN            NaN
# Adrack Humble              House Greyjoy       300.0  5.0           20.0
# Aemon Costayne                 Lannister         NaN  NaN            NaN
#
#                          Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  \
# Name
# Addam Marbrand                         56.0       1         1    1    1    1
# Aegon Frey (Jinglebell)                49.0       1         1    0    0    1
# Aegon Targaryen                         5.0       1         1    0    0    0
# Adrack Humble                          20.0       1         1    0    0    0
# Aemon Costayne                          NaN       1         1    0    0    1
#
#                          FfC  DwD
# Name
# Addam Marbrand             1    0
# Aegon Frey (Jinglebell)    0    0
# Aegon Targaryen            0    1
# Adrack Humble              0    1
# Aemon Costayne             0    0
# 300.0

# %% [markdown]
# ## Creating subsets using relational operators

# %%
df3 = df2['Death Year']<400
# print(df3)
df4 = df2[df3]
df4
# Out:
#                                      Allegiances  Death Year  BoD  \
# Name
# Aegon Frey (Jinglebell)                     None       299.0  3.0
# Adrack Humble                      House Greyjoy       300.0  5.0
# Aemon Targaryen (son of Maekar I)  Night's Watch       300.0  4.0
# Aenys Frey                                  None       300.0  5.0
# Aggar                              House Greyjoy       299.0  2.0
# ...                                          ...         ...  ...
# Young Henly                        Night's Watch       299.0  3.0
# Yurkhaz zo Yunzak                           None       300.0  5.0
# Yezzan Zo Qaggaz                            None       300.0  5.0
# Torwynd the Tame                        Wildling       300.0  5.0
# Talbert Serry                             Tyrell       300.0  4.0
#
#                                    Death Chapter  Book Intro Chapter  Gender  \
# Name
# Aegon Frey (Jinglebell)                     51.0                49.0       1
# Adrack Humble                               20.0                20.0       1
# Aemon Targaryen (son of Maekar I)           35.0                21.0       1
# Aenys Frey                                   NaN                59.0       0
# Aggar                                       56.0                50.0       1
# ...                                          ...                 ...     ...
# Young Henly                                 55.0                55.0       1
# Yurkhaz zo Yunzak                           59.0                47.0       1
# Yezzan Zo Qaggaz                            57.0                25.0       1
# Torwynd the Tame                            73.0                73.0       1
# Talbert Serry                               29.0                29.0       1
#
#                                    Nobility  GoT  CoK  SoS  FfC  DwD
# Name
# Aegon Frey (Jinglebell)                   1    0    0    1    0    0
# Adrack Humble                             1    0    0    0    0    1
# Aemon Targaryen (son of Maekar I)         1    1    0    1    1    0
# Aenys Frey                                1    1    1    1    0    1
# Aggar                                     0    0    1    0    0    0
# ...                                     ...  ...  ...  ...  ...  ...
# Young Henly                               0    0    0    1    0    0
# Yurkhaz zo Yunzak                         0    0    0    0    0    1
# Yezzan Zo Qaggaz                          1    0    0    0    0    1
# Torwynd the Tame                          0    0    0    1    0    0
# Talbert Serry                             1    0    0    0    1    0
#
# [305 rows x 12 columns]

# %% [markdown]
# ## using groupby

# %%
# print(df2['Death Year'].nunique)
df5 = df2.groupby('Death Year').count()
df5
# Out:
#             Allegiances  BoD  Death Chapter  Book Intro Chapter  Gender  \
# Death Year
# 297.0                 3    3              3                   3       3
# 298.0                46   46             46                  46      46
# 299.0               156  156            154                 154     156
# 300.0               100  100             92                  97     100
#
#             Nobility  GoT  CoK  SoS  FfC  DwD
# Death Year
# 297.0              3    3    3    3    3    3
# 298.0             46   46   46   46   46   46
# 299.0            156  156  156  156  156  156
# 300.0            100  100  100  100  100  100

# %%
#df = df.groupby("date").agg({"duration": np.sum, "user_id": pd.Series.nunique})
import numpy as np
df5 = df2.groupby("Death Year").agg({"Death Year":np.sum,"Gender":np.sum})
df5
# Out:
#             Death Year  Gender
# Death Year
# 297.0            891.0       3
# 298.0          13708.0      43
# 299.0          46644.0     141
# 300.0          30000.0      82

# %% [markdown]
# ## Visualization
#
# * data-frame**.plot(x = 'x-column', y = 'y-column')** -> line plot by default
# * data-frame**.plot(x = 'x-column', y = 'y-column', kind = 'scatter')** -> scatter plot
#         arguements for kind -
#             ‘line’ : line plot (default)
#             ‘bar’ : vertical bar plot
#             ‘hist’ : histogram
#             ‘box’ : boxplot
#             ‘pie’ : pie plot
#             ‘scatter’ : scatter plot

# %%
df5.plot(x='Death Year',y='Gender',kind='scatter')
# Out:
# <AxesSubplot:xlabel='Death Year', ylabel='Gender'>

# %% [markdown]
# # Try....
#
# Here is a small excercise to test out your understanding...
#
# ## Three Eyed Raven's Visions (Dataset Column Description) -
#
# * Name - Character name
# * Allegiances - Character house
# * Death Year - Year character died
# * Book of Death - Book character died
# * Death Chapter - Book character died in
# * Book Intro Chapter - Chapter character was introduced in
# * Gender - 1 is male, 0 is female
# * Nobility - 1 is nobel, 0 is a commoner
# * GoT - Appeared in first book
# * CoK - Appeared in second book
# * SoS - Appeared in third book
# * FfC - Appeared in fourth book
# * DwD - Appeared in fifth book
#
# ## White walkers that you have to slay (Tasks) - Perform the following operations
#
# 1. Identify the house with the most deaths
# 2. Identify the chapter in which it's written that "Uncle Benjamin Stark dies".
# 3. Find the total number of female who died in a particular year
# 4. List of all years in which new characters are identified

# %% [markdown]
# ##

# %%
df = pd.read_csv('character-deaths.csv')
df
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)             None       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo             None         NaN            NaN
# 913        Yurkhaz zo Yunzak             None       300.0            5.0
# 914         Yezzan Zo Qaggaz             None       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0              NaN                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2              NaN                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4              NaN                 NaN       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912            NaN                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]

# %%
#Identify the house with the most deaths
df1 = df.groupby(by="Allegiances").count()
df1[df1['Name']==df1['Name'].max()]
# Out:
#              Name  Death Year  Book of Death  Death Chapter  \
# Allegiances
# None          253          76             76             73
#
#              Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  DwD
# Allegiances
# None                        250     253       253  253  253  253  253  253

# %%
#Find the total number of female who died in a particular year
df1 = df[df["Gender"] == 0]
df1[df1['Death Year'] == 299]
# Out:
#                   Name      Allegiances  Death Year  Book of Death  \
# 65               Barra             None       299.0            2.0
# 73     Becca the Baker             None       299.0            3.0
# 126      Catelyn Tully      House Stark       299.0            3.0
# 160      Dacey Mormont            Stark       299.0            3.0
# 193   Donella Hornwood            Stark       299.0            2.0
# 203             Doreah  House Targaryen       299.0            2.0
# 334              Harra             None       299.0            2.0
# 377    Jacelyn Bywater        Lannister       299.0            2.0
# 500  Maerie (Goodwife)             None       299.0            3.0
# 501     Maerie (Whore)             None       299.0            3.0
# 551     Mirri Maz Duur             None       299.0            1.0
# 592              Nolla             None       299.0            3.0
# 678              Randa             None       299.0            3.0
# 811          Tion Frey        Lannister       299.0            3.0
# 905            Ygritte         Wildling       299.0            3.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 65            39.0                35.0       0         0    1    0    0    0
# 73            34.0                34.0       0         0    0    0    1    0
# 126           51.0                 2.0       0         1    1    1    1    0
# 160           51.0                63.0       0         1    1    0    1    0
# 193           35.0                16.0       0         1    0    1    0    0
# 203           12.0                11.0       0         0    1    1    0    0
# 334           64.0                26.0       0         0    0    1    0    0
# 377           19.0                 8.0       0         1    0    1    0    0
# 500           34.0                34.0       0         0    0    0    1    0
# 501           34.0                34.0       0         0    0    0    1    0
# 551           72.0                61.0       0         0    1    0    0    0
# 592           34.0                34.0       0         0    0    0    1    0
# 678           34.0                34.0       0         0    0    0    1    0
# 811           20.0                20.0       0         1    0    0    1    0
# 905           55.0                51.0       0         0    0    1    1    0
#
#      DwD
# 65     0
# 73     0
# 126    0
# 160    0
# 193    0
# 203    0
# 334    0
# 377    0
# 500    0
# 501    0
# 551    0
# 592    0
# 678    0
# 811    0
# 905    0

# %%
#List of all years in which new characters are identified
df[((df['GoT']==1) | (df['CoK']==1) | (df['SoS']==1) | (df['FfC']==1) | (df['DwD']==1))]['Death Year'].unique()
# Out:
# array([ nan, 299., 300., 298., 297.])
